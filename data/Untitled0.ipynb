# %%
import pandas as pd

# 1. Cargar el archivo CSV
from google.colab import files
uploaded = files.upload()

# 2. Visualizar las primeras filas
import pandas as pd

datos = pd.read_csv('4_resultados_agua.csv')

datos.head()
# Out:
#      <input type="file" id="files-4a185df4-bb66-4405-8b30-b71292dfc9de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a185df4-bb66-4405-8b30-b71292dfc9de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Identificar columnas
datos.columns
# Out:
# Index(['Punto', 'Temp', 'pH', 'OD_promedio'], dtype='object')

# %%
# Tipos de datos y estructura
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Punto        5 non-null      object
#  1   Temp         5 non-null      float64
#  2   pH           5 non-null      float64
#  3   OD_promedio  5 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 292.0+ bytes

# %%
# Valores nulos
datos.isnull().sum()
# Out:
# Punto          0
# Temp           0
# pH             0
# OD_promedio    0
# dtype: int64

# %%
# Estadísticas descriptivas
datos.describe()
# Out:
#             Temp        pH  OD_promedio
# count   5.000000  5.000000     5.000000
# mean   23.030000  7.100000     5.680000
# std     2.093621  0.158114     0.712039
# min    19.800000  6.850000     4.900000
# 25%    22.250000  7.050000     5.000000
# 50%    23.650000  7.150000     5.800000
# 75%    24.300000  7.200000     6.200000
# max    25.150000  7.250000     6.500000

# %% [markdown]
# ## Análisis
#
# Se reconocieron las columnas en el dataset, que corresponden a los distintos parámetros de la calidad del agua.
#
# Por medio de la función info(), se analizaron la cantidad de registros y los tipos de datos, dando aval de observar la estructura del conjunto de datos.
#
# Se examinaron los valores nulos por cada columna, esto es importante para reconocer posibles datos faltantes o inconsistencias.
#
# Por último, se originaron estadísticas descriptivas que ayudan a comprender el comportamiento general de los datos, agregando valores promedio, mínimos y máximos.
