# %% [markdown]
# # 🧩 Ejemplo de clase – Introducción a Pandas
#
# Aprenderás los conceptos básicos de `pandas`, la creación de DataFrames y su exploración inicial.

# %%
import pandas as pd

# Crea un DataFrame de ejemplo
datos = pd.DataFrame({
    'sitio': ['Río A', 'Río B', 'Río C'],
    'pH': [7.1, 8.3, 6.2]
})

datos.head()

# %% [markdown]
# ## 🧠 Reflexión
# Describe con tus palabras qué ventajas tiene usar `pandas` frente a listas o diccionarios para manejar datos tabulares.

# %% [markdown]
# ## Juan Zamudio - Camilo Pachon
# Trabajar con panada hace mas rapido el manejo de datos, ademas de que tambien nos ayuda a cambiar la forma en el cual se puede entender la informacion. en lugar de enfocarse en la programacion paso a paso como puede ocurrir con listas o diccionarios, pandas nos permite centrar en el analisis. este proceso hace que sea mas cercano a la realidad en los analisi de datos, donde lo primordial no es solo almacenar informacion, si no que es poder interpretarla y encontrar patrones. en conclucion pandas no solo es una herramienta pontente, si no que esta tambien es mucho mas practica para aprender a pensar los datos de forma organizada y critica.

# %% [markdown]
# ## Ariana Gaitan
# Utilizar pandas frente a listas o diccionarios nos permite pensar en datos como en una tabla completa y no en elementos sueltos, por otro lado con el uso de diccionarios y las listas, se debe transformar, filtrar y recorrer manualmente cada parte, panda comprende de funciones optimizadas para hacerlo en pocas líneas y de manera más legible, convirtiendo el proceso más claro, eficiente y cercano a como se maneja los datos en la vida real.

# %% [markdown]
# ## Mariana Villada
# Pandas no solo simplifica el trabajo, sino que lo hace más escalable. Con listas o diccionarios, manejar pocos datos puede ser sencillo, pero a medida que la información crece, el código se vuelve más complejo y difícil de mantener. En cambio, pandas está diseñado para trabajar con grandes volúmenes de datos sin perder claridad. Esto permite que el análisis sea más sostenible en el tiempo, ya que el mismo enfoque sirve tanto para conjuntos pequeños como grandes. En consecuencia, usar pandas no es solo una cuestión de comodidad, sino de adoptar una forma de trabajo más robusta y preparada para problemas reales.

# %% [markdown]
# ## Felipe Morera
# Pandas aporta coherencia al trabajar con datos tabulares. Con listas o diccionarios, es fácil que la estructura se desordene o que cada parte del código maneje los datos de forma distinta. En cambio, pandas mantiene una organización clara (filas y columnas), lo que ayuda a evitar inconsistencias. Esto no solo mejora la calidad del análisis, sino que también facilita entender y compartir el trabajo con otras personas. En ese sentido, pandas no solo optimiza el manejo de datos, sino que también promueve buenas prácticas y un trabajo más estructurado.
